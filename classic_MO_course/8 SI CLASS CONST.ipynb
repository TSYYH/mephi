# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.metrics import accuracy_score, f1_score, classification_report
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from catboost import CatBoostClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.svm import SVC

# %%
# загрузка данных
df = pd.read_csv('D:\\notebooks\\sem2\\Classic_MO\\course\\df_SI_const.csv')

# %%
random_state = 17
test_size = 0.2

# модели
models = {
    'LogisticRegression': LogisticRegression(max_iter=1000),
    'DecisionTree': DecisionTreeClassifier(random_state=random_state),
    'RandomForest': RandomForestClassifier(random_state=random_state),
    'CatBoost': CatBoostClassifier(verbose=0, random_state=random_state),
    'SVC': SVC(probability=True)
}

# параметры для GridSearch
param_grids = {
    'LogisticRegression': {'C': [0.1, 1, 10]},
    'DecisionTree': {'max_depth': [3, 5, 7, 10, None]},
    'RandomForest': {'n_estimators': [50, 100], 'max_depth': [5, 10, None]},
    'CatBoost': {'depth': [4, 6, 8], 'learning_rate': [0.01, 0.1]},
    'SVC': {'C': [0.1, 1, 10], 'kernel': ['rbf', 'linear']}
}

# %%
features = df.drop(columns='greater_const')
target = df['greater_const']

X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=test_size, random_state=random_state)

# %%
results = []

# обучение
for name, model in models.items():
    print(f"\n{name}")
    grid = GridSearchCV(model, param_grids[name], cv=5, scoring='f1_macro', n_jobs=-1)
    grid.fit(X_train, y_train)
    best_model = grid.best_estimator_
    
    y_pred = best_model.predict(X_test)
    
    acc = accuracy_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred, average='macro')
    
    print("Best Parameters:", grid.best_params_)
    print("Accuracy:", acc)
    print("F1 Score (macro):", f1)
    print("Classification Report:\n", classification_report(y_test, y_pred))

    results.append({
        'Model': name,
        'Best Params': grid.best_params_,
        'accuracy': acc,
        'f1_score': f1
    })

# сводная таблица результатов
pd.DataFrame(results)
# Out:
# LogisticRegression
# Best Parameters: {'C': 1}
# Accuracy: 0.6915422885572139
# F1 Score (macro): 0.6243670122980468
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.74      0.84      0.78       134
#            1       0.55      0.40      0.47        67
#
#     accuracy                           0.69       201
#    macro avg       0.64      0.62      0.62       201
# weighted avg       0.67      0.69      0.68       201
#
#
# DecisionTree
# Best Parameters: {'max_depth': 7}
# Accuracy: 0.6069651741293532
# F1 Score (macro): 0.5656372240610553
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.71      0.69      0.70       134
#            1       0.42      0.45      0.43        67
#
#     accuracy                           0.61       201
#    macro avg       0.56      0.57      0.57       201
# weighted avg       0.61      0.61      0.61       201
#
#
# RandomForest
# Best Parameters: {'max_depth': 10, 'n_estimators': 50}
# Accuracy: 0.7064676616915423
# F1 Score (macro): 0.651216140701744
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.76      0.83      0.79       134
#            1       0.57      0.46      0.51        67
#
#     accuracy                           0.71       201
#    macro avg       0.66      0.65      0.65       201
# weighted avg       0.69      0.71      0.70       201
#
#
# CatBoost
# Best Parameters: {'depth': 6, 'learning_rate': 0.01}
# Accuracy: 0.6915422885572139
# F1 Score (macro): 0.6317375886524823
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.74      0.82      0.78       134
#            1       0.55      0.43      0.48        67
#
#     accuracy                           0.69       201
#    macro avg       0.65      0.63      0.63       201
# weighted avg       0.68      0.69      0.68       201
#
#
# SVC
# Best Parameters: {'C': 10, 'kernel': 'rbf'}
# Accuracy: 0.6417910447761194
# F1 Score (macro): 0.6054525627044711
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.74      0.71      0.73       134
#            1       0.47      0.51      0.49        67
#
#     accuracy                           0.64       201
#    macro avg       0.60      0.61      0.61       201
# weighted avg       0.65      0.64      0.65       201
#                 Model                            Best Params  accuracy  \
# 0  LogisticRegression                               {'C': 1}  0.691542
# 1        DecisionTree                       {'max_depth': 7}  0.606965
# 2        RandomForest  {'max_depth': 10, 'n_estimators': 50}  0.706468
# 3            CatBoost    {'depth': 6, 'learning_rate': 0.01}  0.691542
# 4                 SVC             {'C': 10, 'kernel': 'rbf'}  0.641791
#
#    f1_score
# 0  0.624367
# 1  0.565637
# 2  0.651216
# 3  0.631738
# 4  0.605453
